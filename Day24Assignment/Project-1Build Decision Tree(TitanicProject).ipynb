# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn import preprocessing
from sklearn .ensemble import RandomForestClassifier

# %%
titanic_train=pd.read_csv("Decision Tree Dataset/train.csv")

# %%
titanic_train["Age"].mean()
# Out:
# 32.69985376827896

# %%
new_age_var=np.where(titanic_train["Age"].isnull(),32,titanic_train["Age"])
titanic_train["Age"]=new_age_var

# %%
label_encoder=preprocessing.LabelEncoder()
encoded_sex=label_encoder.fit_transform(titanic_train["Sex"])

# %%
tree_model=tree.DecisionTreeClassifier()
tree_model.fit(X=pd.DataFrame(encoded_sex),y=titanic_train["Survived"])
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
with open("Dtree1.dot",'w') as f:
    f=tree.export_graphviz(tree_model,feature_names=["Sex"],out_file=f);

# %%
predictors=pd.DataFrame([encoded_sex,titanic_train["Age"],titanic_train["Fare"]]).T

# %%
tree_model.fit(X=predictors,y=titanic_train["Survived"])
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
with open("Titanic.dot",'w') as f:
    f=tree.export_graphviz(tree_model,feature_names=["Sex","Age","Fare"],out_file=f)

# %%
tree_model.score(X=predictors,y=titanic_train["Survived"])
# Out:
# 0.9763779527559056

# %% [markdown]
# <b>By Passing Independent variables Sex,Age and Fare it gives higher Accuracy Of Model up 97%.</b><br>

# %%
# Decision tree for prediction:
titanic_test=pd.read_csv("Decision Tree Dataset/test.csv")
titanic_test["Age"].mean()
# Out:
# 33.23741007194245

# %%
new_age_var=np.where(titanic_test["Age"].isnull(),33,titanic_test["Age"])
titanic_test["Age"]=new_age_var

# %%
encoded_sex_test=label_encoder.fit_transform(titanic_test["Sex"])
test_features=pd.DataFrame([encoded_sex_test,titanic_test["Age"],titanic_test["Fare"]]).T

# %%
test_preds=tree_model.predict(X=test_features)
predicted_output=pd.DataFrame({"PassengrId":titanic_test["PassengerId"],"Survived":test_preds})

# %%
predicted_output.to_csv("Titanic output.csv",index=False);

# %%
label_encoder=preprocessing.LabelEncoder()
titanic_train["Sex"]=label_encoder.fit_transform(titanic_train["Sex"])

# %% [markdown]
# # Decision Tree:-

# %%
DecisionTreeClassifier=tree.DecisionTreeClassifier(max_depth=6)

# %%
DecisionTreeClassifier.fit(titanic_train[["Age","Fare","Sex"]],titanic_train["Survived"])
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
plt.rcParams["figure.figsize"] = (200,100)

# %%
tree.plot_tree(DecisionTreeClassifier,filled = True);
